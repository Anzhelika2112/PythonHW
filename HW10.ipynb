# %% [markdown]
# ##Задача 44.
#
# *В ячейке ниже представлен код генерирующий DataFrame, которая состоит всегоиз 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?*
#
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.sample(5)
# Out:
#    whoAmI
# 16  robot
# 8   robot
# 0   robot
# 2   human
# 4   human

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
# 5      0
# 6      1
# 7      0
# 8      0
# 9      0
# 10     1
# 11     1
# 12     1
# 13     1
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
